# %% [markdown]
# # Plotting feature importance

# %%
import train as tn
reload(tn)

import plotting
reload(plotting)

import util as ut

import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# %matplotlib inline

import numpy as np
# Out:
# Welcome to ROOTaaS 6.06/08

# %%
path  = "./batch_outfiles/Train_Configurable_Refactor_higgs_model_dep_2273534"
name  = "Train_Configurable_Refactor_higgs_model_dep_2273534"
fitter = tn.IO.load(name,path,nodata=True)
# Out:
# ./batch_outfiles/Train_Configurable_Refactor_higgs_model_dep_2273534
# ./batch_outfiles/Train_Configurable_Refactor_higgs_model_dep_2273534/Train_Configurable_Refactor_higgs_model_dep_2273534.pkl.gz
# loading pickle ./batch_outfiles/Train_Configurable_Refactor_higgs_model_dep_2273534/Train_Configurable_Refactor_higgs_model_dep_2273534.pkl.gz

# %%
def featureImpPlot (features, features_importance, title) :
    y_position = np.arange(len(features))

    plt.bar(y_position, features_importance*100, align='center', alpha=0.5)
    plt.xticks(y_position, features,rotation='90')
    plt.ylabel('feature importance [%]')
    plt.title("trained class: " + title)
    plt.show()

# %%
classes = ['class','recoPt']#,'recoNjets2p5']
"""
Gini importance is used by sklearn
"""
for c in classes :
    feature, feature_imp = fitter.featureImportance(c)
    print(feature_imp)
    featureImpPlot(feature,feature_imp,title=c)
# Out:
# [ 0.28924844  0.41350903  0.14782473  0.14941781]
# KeyErrorTraceback (most recent call last)
# <ipython-input-9-1580861decc4> in <module>()
#       4 """
#       5 for c in classes :
# ----> 6     feature, feature_imp = fitter.featureImportance(c)
#       7     print(feature_imp)
#       8     featureImpPlot(feature,feature_imp,title=c)
#
# /mnt/t3nfs01/data01/shome/jandrejk/higgs_model_dep/train.pyc in featureImportance(self, column)
#     221     # ---------------------------------------------------------------------------
#     222     def featureImportance(self, column) :
# --> 223         clf = self.clfs[column]
#     224         inputs = clf.inputs
#     225         inputs_importance =clf.feature_importances_
#
# KeyError: 'recoPt'
